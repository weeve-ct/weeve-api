# %%
import requests
import time
import re
import json
import os

# %%
user_cred = {
    'username': 'jill@cornell.edu',
    'password': 'password'
}
r = requests.post('http://localhost:8080/auth/login', json=user_cred)
token = r.json()['token']
auth_headers = {'authorization': 'bearer {}'.format(token)}

# %%
post_id = 28
r = requests.get('http://localhost:8080/post/{}'.format(post_id), headers=auth_headers)
if not r.status_code in range(200,300): print(r.text)

payload = r.json()['post']
body = payload['body']
title = payload['title']
explicit_tags = payload['explicit_tags']
post_id = time.time()

print(title)
# Out:
# Metabase in Google Kubernetes Engine

# %%
fp = re.sub(r'\s+','_',title.strip().lower()) + '.json'
fp = os.path.join('./sample-data/',fp)

with open(fp, 'w') as f:
    f.write(json.dumps({
        'body': body,
        'title': title,
        'explicit_tags': explicit_tags
    }))

# %%
import base64

# %%
base64.b64decode()

# %%
text = '''{"collaborators":[],"title":"fundamental React.js concepts","explicit_tags":["react","js","tutorial"],"body":"{\"blocks\":[{\"key\":\"escdl\",\"text\":\"Fundamental #1: React is all about components\",\"type\":\"header-three\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":45,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":45,\"style\":\"fontsize-34\"},{\"offset\":0,\"length\":45,\"style\":\"fontfamily-medium-content-sans-serif-font, \\\"Lucida Grande\\\", \\\"Lucida Sans Unicode\\\", \\\"Lucida Sans\\\", Geneva, Arial, sans-serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"2o5cc\",\"text\":\"React is designed around the concept of reusable components. You define small components and you put them together to form bigger components.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":141,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":141,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":141,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":141,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"foepi\",\"text\":\"All components small or big are reusable, even across different projects.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":73,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":73,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":73,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":73,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5g3mp\",\"text\":\"A React component — in its simplest form — is a plain-old JavaScript function:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":78,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":78,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":78,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":78,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"a1dag\",\"text\":\"// Example 1\\n// https://jscomplete.com/repl?j=Sy3QAdKHW\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":13,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":13,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":13,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":13,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":0,\"length\":12,\"style\":\"BOLD\"},{\"offset\":16,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":16,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":16,\"length\":39,\"key\":0}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"apcue\",\"text\":\"function Button (props) {\\n  // Returns a DOM element here. For example:\\n  return <button type=\\\"submit\\\">{props.label}</button>;\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":25,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":26,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":72,\"length\":54,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":127,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":25,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":26,\"length\":45,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":72,\"length\":54,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":127,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":25,\"style\":\"fontsize-16\"},{\"offset\":26,\"length\":45,\"style\":\"fontsize-16\"},{\"offset\":72,\"length\":54,\"style\":\"fontsize-16\"},{\"offset\":127,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":25,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":26,\"length\":45,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":72,\"length\":54,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":127,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"636ra\",\"text\":\"// To render the Button component to the browser\\nReactDOM.render(<Button label=\\\"Save\\\" />, mountNode)\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":48,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":49,\"length\":51,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":48,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":49,\"length\":51,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":48,\"style\":\"fontsize-16\"},{\"offset\":49,\"length\":51,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":48,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":49,\"length\":51,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"e1t0k\",\"text\":\"The curly braces used for the button label are explained below. Don’t worry about them now. ReactDOM will also be explained later, but if you want to test this example and all upcoming code examples, the above render function is what you need.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":91,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":92,\"length\":8,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":101,\"length\":108,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":210,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":217,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":91,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":92,\"length\":8,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":101,\"length\":108,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":210,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":217,\"length\":26,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":91,\"style\":\"fontsize-21\"},{\"offset\":92,\"length\":8,\"style\":\"fontsize-21\"},{\"offset\":101,\"length\":108,\"style\":\"fontsize-21\"},{\"offset\":210,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":217,\"length\":26,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":91,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":92,\"length\":8,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":101,\"length\":108,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":210,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":217,\"length\":26,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":92,\"length\":8,\"style\":\"CODE\"},{\"offset\":210,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"dn0vi\",\"text\":\"The second argument to ReactDOM.render is the destination DOM element which React is going to take over and control. In the jsComplete React Playground, you can just use the special variable mountNode\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":23,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":84,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":124,\"length\":66,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":191,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":23,\"length\":15,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":39,\"length\":84,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":124,\"length\":66,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":191,\"length\":9,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":23,\"length\":15,\"style\":\"fontsize-21\"},{\"offset\":39,\"length\":84,\"style\":\"fontsize-21\"},{\"offset\":124,\"length\":66,\"style\":\"fontsize-21\"},{\"offset\":191,\"length\":9,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":15,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":39,\"length\":84,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":124,\"length\":66,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":191,\"length\":9,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":15,\"style\":\"CODE\"},{\"offset\":191,\"length\":9,\"style\":\"CODE\"},{\"offset\":124,\"length\":27,\"style\":\"color-inherit\"},{\"offset\":124,\"length\":27,\"style\":\"bgcolor-transparent\"}],\"entityRanges\":[{\"offset\":124,\"length\":27,\"key\":1}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"b6gjb\",\"text\":\"Fundamental #2: What the flux is JSX?\",\"type\":\"header-three\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":37,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":37,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":37,\"style\":\"fontsize-34\"},{\"offset\":0,\"length\":37,\"style\":\"fontfamily-medium-content-sans-serif-font, \\\"Lucida Grande\\\", \\\"Lucida Sans Unicode\\\", \\\"Lucida Sans\\\", Geneva, Arial, sans-serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"ah6a0\",\"text\":\"Example 1 above can be written in pure React.js without JSX as follows:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":71,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":71,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":71,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":71,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"ch9pa\",\"text\":\"// Example 2 -  React component without JSX\\n// https://jscomplete.com/repl?j=HyiEwoYB-\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":44,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":44,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":44,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":44,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":47,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":47,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":47,\"length\":39,\"key\":2}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"7gu8a\",\"text\":\"function Button (props) {\\n  return React.createElement(\\n    \\\"button\\\",\\n    { type: \\\"submit\\\" },\\n    props.label\\n  );\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":25,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":26,\"length\":29,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":56,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":70,\"length\":23,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":94,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":110,\"length\":4,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":115,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":25,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":26,\"length\":29,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":56,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":70,\"length\":23,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":94,\"length\":15,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":110,\"length\":4,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":115,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":25,\"style\":\"fontsize-16\"},{\"offset\":26,\"length\":29,\"style\":\"fontsize-16\"},{\"offset\":56,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":70,\"length\":23,\"style\":\"fontsize-16\"},{\"offset\":94,\"length\":15,\"style\":\"fontsize-16\"},{\"offset\":110,\"length\":4,\"style\":\"fontsize-16\"},{\"offset\":115,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":25,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":26,\"length\":29,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":56,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":70,\"length\":23,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":94,\"length\":15,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":110,\"length\":4,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":115,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5vhqg\",\"text\":\"// To use Button, you would do something like\\nReactDOM.render(\\n  React.createElement(Button, { label: \\\"Save\\\" }),\\n  mountNode\\n);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":46,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":63,\"length\":49,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":113,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":125,\"length\":2,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":45,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":46,\"length\":16,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":63,\"length\":49,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":113,\"length\":11,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":125,\"length\":2,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":45,\"style\":\"fontsize-16\"},{\"offset\":46,\"length\":16,\"style\":\"fontsize-16\"},{\"offset\":63,\"length\":49,\"style\":\"fontsize-16\"},{\"offset\":113,\"length\":11,\"style\":\"fontsize-16\"},{\"offset\":125,\"length\":2,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":45,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":46,\"length\":16,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":63,\"length\":49,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":113,\"length\":11,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":125,\"length\":2,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"e5d9d\",\"text\":\"The createElement function is the main function in the React top-level API. It’s 1 of a total of 8 things in that level that you need to learn. That’s how small the React API is.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":4,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":18,\"length\":160,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":3,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":4,\"length\":13,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":18,\"length\":160,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-21\"},{\"offset\":4,\"length\":13,\"style\":\"fontsize-21\"},{\"offset\":18,\"length\":160,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":13,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":18,\"length\":160,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":13,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5tip9\",\"text\":\"Much like the DOM itself having a document.createElement function to create an element specified by a tag name, React’s createElement function is a higher-level function that can do what document.createElement does, but it can also be used to create an element to represent a React component. We did the latter when we used the Button component in Example 2 above.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":33,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":34,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":57,\"length\":62,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":120,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":134,\"length\":52,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":187,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":210,\"length\":117,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":328,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":335,\"length\":29,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":33,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":34,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":57,\"length\":62,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":120,\"length\":13,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":134,\"length\":52,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":187,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":210,\"length\":117,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":328,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":335,\"length\":29,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":33,\"style\":\"fontsize-21\"},{\"offset\":34,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":57,\"length\":62,\"style\":\"fontsize-21\"},{\"offset\":120,\"length\":13,\"style\":\"fontsize-21\"},{\"offset\":134,\"length\":52,\"style\":\"fontsize-21\"},{\"offset\":187,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":210,\"length\":117,\"style\":\"fontsize-21\"},{\"offset\":328,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":335,\"length\":29,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":33,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":34,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":57,\"length\":62,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":120,\"length\":13,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":134,\"length\":52,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":187,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":210,\"length\":117,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":328,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":335,\"length\":29,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":34,\"length\":22,\"style\":\"CODE\"},{\"offset\":120,\"length\":13,\"style\":\"CODE\"},{\"offset\":187,\"length\":22,\"style\":\"CODE\"},{\"offset\":328,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"fopu1\",\"text\":\"Unlike document.createElement, React’s createElement accepts a dynamic number of arguments after the second one to represent the children of the created element. So createElement actually creates a tree.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":7,\"length\":31,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":53,\"length\":75,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":129,\"length\":8,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":138,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":165,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":179,\"length\":18,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":198,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":7,\"length\":31,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":39,\"length\":13,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":53,\"length\":75,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":129,\"length\":8,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":138,\"length\":26,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":165,\"length\":13,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":179,\"length\":18,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":198,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":7,\"length\":31,\"style\":\"fontsize-21\"},{\"offset\":39,\"length\":13,\"style\":\"fontsize-21\"},{\"offset\":53,\"length\":75,\"style\":\"fontsize-21\"},{\"offset\":129,\"length\":8,\"style\":\"fontsize-21\"},{\"offset\":138,\"length\":26,\"style\":\"fontsize-21\"},{\"offset\":165,\"length\":13,\"style\":\"fontsize-21\"},{\"offset\":179,\"length\":18,\"style\":\"fontsize-21\"},{\"offset\":198,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":7,\"length\":31,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":39,\"length\":13,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":53,\"length\":75,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":129,\"length\":8,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":138,\"length\":26,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":165,\"length\":13,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":179,\"length\":18,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":198,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":7,\"length\":22,\"style\":\"CODE\"},{\"offset\":39,\"length\":13,\"style\":\"CODE\"},{\"offset\":165,\"length\":13,\"style\":\"CODE\"},{\"offset\":129,\"length\":8,\"style\":\"BOLD\"},{\"offset\":198,\"length\":4,\"style\":\"BOLD\"},{\"offset\":202,\"length\":1,\"style\":\"ITALIC\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5vjvu\",\"text\":\"Here’s an example of that:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":26,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":26,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":26,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bf92l\",\"text\":\"// Example 3 -  React’s createElement API\\n// https://jscomplete.com/repl?j=r1GNoiFBb\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":41,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":42,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":41,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":42,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":41,\"style\":\"fontsize-16\"},{\"offset\":42,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":41,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":42,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":45,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":45,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":45,\"length\":39,\"key\":3}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"35f4i\",\"text\":\"const InputForm = React.createElement(\\n  \\\"form\\\",\\n  { target: \\\"_blank\\\", action: \\\"https://google.com/search\\\" },\\n  React.createElement(\\\"div\\\", null, \\\"Enter input and click Search\\\"),\\n  React.createElement(\\\"input\\\", { name: \\\"q\\\", className: \\\"input\\\" }),\\n  React.createElement(Button, { label: \\\"Search\\\" })\\n);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":49,\"length\":60,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":110,\"length\":67,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":178,\"length\":66,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":245,\"length\":50,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":296,\"length\":2,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":49,\"length\":60,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":110,\"length\":67,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":178,\"length\":66,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":245,\"length\":50,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":296,\"length\":2,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":49,\"length\":60,\"style\":\"fontsize-16\"},{\"offset\":110,\"length\":67,\"style\":\"fontsize-16\"},{\"offset\":178,\"length\":66,\"style\":\"fontsize-16\"},{\"offset\":245,\"length\":50,\"style\":\"fontsize-16\"},{\"offset\":296,\"length\":2,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":49,\"length\":60,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":110,\"length\":67,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":178,\"length\":66,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":245,\"length\":50,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":296,\"length\":2,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":80,\"length\":25,\"style\":\"color-inherit\"},{\"offset\":80,\"length\":25,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":80,\"length\":25,\"key\":4}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"3h4l7\",\"text\":\"// InputForm uses the Button component, so we need that too:\\nfunction Button (props) {\\n  return React.createElement(\\n    \\\"button\\\",\\n    { type: \\\"submit\\\" },\\n    props.label\\n  );\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":60,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":61,\"length\":25,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":87,\"length\":29,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":117,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":131,\"length\":23,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":155,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":171,\"length\":4,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":176,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":60,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":61,\"length\":25,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":87,\"length\":29,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":117,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":131,\"length\":23,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":155,\"length\":15,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":171,\"length\":4,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":176,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":60,\"style\":\"fontsize-16\"},{\"offset\":61,\"length\":25,\"style\":\"fontsize-16\"},{\"offset\":87,\"length\":29,\"style\":\"fontsize-16\"},{\"offset\":117,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":131,\"length\":23,\"style\":\"fontsize-16\"},{\"offset\":155,\"length\":15,\"style\":\"fontsize-16\"},{\"offset\":171,\"length\":4,\"style\":\"fontsize-16\"},{\"offset\":176,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":60,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":61,\"length\":25,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":87,\"length\":29,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":117,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":131,\"length\":23,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":155,\"length\":15,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":171,\"length\":4,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":176,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"c3ucb\",\"text\":\"// Then we can use InputForm directly with .render\\nReactDOM.render(InputForm, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":50,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":51,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":50,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":51,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":50,\"style\":\"fontsize-16\"},{\"offset\":51,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":50,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":51,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5iq2o\",\"text\":\"Note a few things about the example above:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":42,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":42,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":42,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"69u2o\",\"text\":\"InputForm is not a React component; it’s just a React element. This is why we used it directly in the ReactDOM.render call and not with <InputForm />.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":54,\"length\":47,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":102,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":118,\"length\":17,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":136,\"length\":14,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":10,\"length\":43,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":54,\"length\":47,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":102,\"length\":15,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":118,\"length\":17,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":136,\"length\":14,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-20\"},{\"offset\":10,\"length\":43,\"style\":\"fontsize-20\"},{\"offset\":54,\"length\":47,\"style\":\"fontsize-20\"},{\"offset\":102,\"length\":15,\"style\":\"fontsize-20\"},{\"offset\":118,\"length\":17,\"style\":\"fontsize-20\"},{\"offset\":136,\"length\":14,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":10,\"length\":43,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":54,\"length\":47,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":102,\"length\":15,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":118,\"length\":17,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":136,\"length\":14,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-21\"},{\"offset\":10,\"length\":43,\"style\":\"fontsize-21\"},{\"offset\":54,\"length\":47,\"style\":\"fontsize-21\"},{\"offset\":102,\"length\":15,\"style\":\"fontsize-21\"},{\"offset\":118,\"length\":17,\"style\":\"fontsize-21\"},{\"offset\":136,\"length\":14,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":10,\"length\":43,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":54,\"length\":47,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":102,\"length\":15,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":118,\"length\":17,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":136,\"length\":14,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":0,\"length\":9,\"style\":\"CODE\"},{\"offset\":102,\"length\":15,\"style\":\"CODE\"},{\"offset\":136,\"length\":13,\"style\":\"CODE\"},{\"offset\":54,\"length\":7,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"67i59\",\"text\":\"The React.createElement function accepted multiple arguments after the first two. Its list of arguments starting from the 3rd one comprises the list of children for the created element.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":4,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":24,\"length\":161,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":3,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":4,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":24,\"length\":161,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-20\"},{\"offset\":4,\"length\":19,\"style\":\"fontsize-20\"},{\"offset\":24,\"length\":161,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":4,\"length\":19,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":24,\"length\":161,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-21\"},{\"offset\":4,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":24,\"length\":161,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":24,\"length\":161,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":19,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"8i3ie\",\"text\":\"We were able to nest React.createElement calls because it’s all JavaScript.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":20,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":21,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":41,\"length\":34,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":20,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":21,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":41,\"length\":34,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":20,\"style\":\"fontsize-20\"},{\"offset\":21,\"length\":19,\"style\":\"fontsize-20\"},{\"offset\":41,\"length\":34,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":20,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":21,\"length\":19,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":41,\"length\":34,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":20,\"style\":\"fontsize-21\"},{\"offset\":21,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":41,\"length\":34,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":20,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":21,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":41,\"length\":34,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":21,\"length\":19,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"f7c57\",\"text\":\"The second argument to React.createElement can be null or an empty object when no attributes or props are needed for the element.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":23,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":43,\"length\":86,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":23,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":43,\"length\":86,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":22,\"style\":\"fontsize-20\"},{\"offset\":23,\"length\":19,\"style\":\"fontsize-20\"},{\"offset\":43,\"length\":86,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":22,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":23,\"length\":19,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":43,\"length\":86,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":23,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":43,\"length\":86,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":43,\"length\":86,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":19,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"6dstt\",\"text\":\"We can mix HTML element with React elements.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":44,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":44,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":44,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":44,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":44,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":44,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"ba7dm\",\"text\":\"React’s API tries to be as close to the DOM API as possible, that’s why we use className instead of class for the input element. Secretly, we all wish the React’s API would become part of the DOM API itself. Because, you know, it’s much much better.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":78,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":79,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":89,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":100,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":106,\"length\":143,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":78,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":79,\"length\":9,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":89,\"length\":10,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":100,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":106,\"length\":143,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":78,\"style\":\"fontsize-20\"},{\"offset\":79,\"length\":9,\"style\":\"fontsize-20\"},{\"offset\":89,\"length\":10,\"style\":\"fontsize-20\"},{\"offset\":100,\"length\":5,\"style\":\"fontsize-20\"},{\"offset\":106,\"length\":143,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":78,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":79,\"length\":9,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":89,\"length\":10,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":100,\"length\":5,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":106,\"length\":143,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":78,\"style\":\"fontsize-21\"},{\"offset\":79,\"length\":9,\"style\":\"fontsize-21\"},{\"offset\":89,\"length\":10,\"style\":\"fontsize-21\"},{\"offset\":100,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":106,\"length\":143,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":78,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":79,\"length\":9,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":89,\"length\":10,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":100,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":106,\"length\":143,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":79,\"length\":9,\"style\":\"CODE\"},{\"offset\":100,\"length\":5,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"36f5o\",\"text\":\"The code above is what the browser understands when you include the React library. The browser does not deal with any JSX business. However, we humans like to see and work with HTML instead of these createElement calls (imagine building a website with just document.createElement, which you can!). This is why the JSX compromise exists. Instead of writing the form above with React.createElement calls, we can write it with a syntax very similar to HTML:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":198,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":199,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":213,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":257,\"length\":118,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":376,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":396,\"length\":58,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":198,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":199,\"length\":13,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":213,\"length\":43,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":257,\"length\":118,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":376,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":396,\"length\":58,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":198,\"style\":\"fontsize-21\"},{\"offset\":199,\"length\":13,\"style\":\"fontsize-21\"},{\"offset\":213,\"length\":43,\"style\":\"fontsize-21\"},{\"offset\":257,\"length\":118,\"style\":\"fontsize-21\"},{\"offset\":376,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":396,\"length\":58,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":198,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":199,\"length\":13,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":213,\"length\":43,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":257,\"length\":118,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":376,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":396,\"length\":58,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":199,\"length\":13,\"style\":\"CODE\"},{\"offset\":257,\"length\":22,\"style\":\"CODE\"},{\"offset\":376,\"length\":19,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"auab0\",\"text\":\"// Example 4 - JSX (compare with Example 3)\\n// https://jscomplete.com/repl?j=SJWy3otHW\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":44,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":44,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":44,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":44,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":47,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":47,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":47,\"length\":39,\"key\":5}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"4h6j2\",\"text\":\"const InputForm =\\n  <form target=\\\"_blank\\\" action=\\\"https://google.com/search\\\">\\n    <div>Enter input and click Search</div>\\n    <input name=\\\"q\\\" className=\\\"input\\\" />\\n    <Button label=\\\"Search\\\" />\\n  </form>;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":17,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":18,\"length\":59,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":78,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":122,\"length\":40,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":163,\"length\":29,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":193,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":17,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":18,\"length\":59,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":78,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":122,\"length\":40,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":163,\"length\":29,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":193,\"length\":10,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":17,\"style\":\"fontsize-16\"},{\"offset\":18,\"length\":59,\"style\":\"fontsize-16\"},{\"offset\":78,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":122,\"length\":40,\"style\":\"fontsize-16\"},{\"offset\":163,\"length\":29,\"style\":\"fontsize-16\"},{\"offset\":193,\"length\":10,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":17,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":18,\"length\":59,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":78,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":122,\"length\":40,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":163,\"length\":29,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":193,\"length\":10,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":50,\"length\":25,\"style\":\"color-inherit\"},{\"offset\":50,\"length\":25,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":50,\"length\":25,\"key\":6}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"b7afv\",\"text\":\"// InputForm \\\"still\\\" uses the Button component, so we need that too.\\n// Either JSX or normal form would do\\nfunction Button (props) {\\n  // Returns a DOM element here. For example:\\n  return <button type=\\\"submit\\\">{props.label}</button>;\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":68,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":69,\"length\":37,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":107,\"length\":25,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":133,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":179,\"length\":54,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":234,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":68,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":69,\"length\":37,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":107,\"length\":25,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":133,\"length\":45,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":179,\"length\":54,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":234,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":68,\"style\":\"fontsize-16\"},{\"offset\":69,\"length\":37,\"style\":\"fontsize-16\"},{\"offset\":107,\"length\":25,\"style\":\"fontsize-16\"},{\"offset\":133,\"length\":45,\"style\":\"fontsize-16\"},{\"offset\":179,\"length\":54,\"style\":\"fontsize-16\"},{\"offset\":234,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":68,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":69,\"length\":37,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":107,\"length\":25,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":133,\"length\":45,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":179,\"length\":54,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":234,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bhiga\",\"text\":\"// Then we can use InputForm directly with .render\\nReactDOM.render(InputForm, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":50,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":51,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":50,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":51,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":50,\"style\":\"fontsize-16\"},{\"offset\":51,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":50,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":51,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"1jr2c\",\"text\":\"Note a few things about the above:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":34,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":34,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":34,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":34,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"84ksg\",\"text\":\"It’s not HTML. For example, we’re still doing className instead of class.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":46,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":56,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":67,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":45,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":46,\"length\":9,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":56,\"length\":10,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":67,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":45,\"style\":\"fontsize-20\"},{\"offset\":46,\"length\":9,\"style\":\"fontsize-20\"},{\"offset\":56,\"length\":10,\"style\":\"fontsize-20\"},{\"offset\":67,\"length\":6,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":45,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":46,\"length\":9,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":56,\"length\":10,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":67,\"length\":6,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":45,\"style\":\"fontsize-21\"},{\"offset\":46,\"length\":9,\"style\":\"fontsize-21\"},{\"offset\":56,\"length\":10,\"style\":\"fontsize-21\"},{\"offset\":67,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":45,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":46,\"length\":9,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":56,\"length\":10,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":67,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":46,\"length\":9,\"style\":\"CODE\"},{\"offset\":67,\"length\":5,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"cbtp7\",\"text\":\"We’re still considering what looks like HTML above as JavaScript. See how I added a semicolon at the end.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":105,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":105,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":105,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":105,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":105,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":105,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"84l42\",\"text\":\"What we wrote above (Example 4) is JSX. Yet, what we took to the browser is the compiled version of it (Example 3). To make that happen, we need to use a pre-processor to convert the JSX version into the React.createElementversion.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":203,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":204,\"length\":27,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":203,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":204,\"length\":27,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":203,\"style\":\"fontsize-21\"},{\"offset\":204,\"length\":27,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":203,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":204,\"length\":27,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":204,\"length\":19,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"69gko\",\"text\":\"That is JSX. It’s a compromise that allows us to write our React components in a syntax similar to HTML, which is a pretty good deal.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":133,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":133,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":133,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":133,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5j0lm\",\"text\":\"Fundamental #3: You can use JavaScript expressions anywhere in JSX\",\"type\":\"header-three\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":66,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":66,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":66,\"style\":\"fontsize-34\"},{\"offset\":0,\"length\":66,\"style\":\"fontfamily-medium-content-sans-serif-font, \\\"Lucida Grande\\\", \\\"Lucida Sans Unicode\\\", \\\"Lucida Sans\\\", Geneva, Arial, sans-serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"6fqs9\",\"text\":\"Inside a JSX section, you can use any JavaScript expression within a pair of curly braces.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":90,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":90,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":90,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":90,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"8qvi9\",\"text\":\"// Example 5 -  Using JavaScript expressions in JSX\\n// https://jscomplete.com/repl?j=SkNN3oYSW\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":51,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":52,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":51,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":52,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":51,\"style\":\"fontsize-16\"},{\"offset\":52,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":51,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":52,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":55,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":55,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":55,\"length\":39,\"key\":7}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"79k9e\",\"text\":\"const RandomValue = () => \\n  <div>\\n    { Math.floor(Math.random() * 100) }\\n  </div>;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":27,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":35,\"length\":39,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":75,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":26,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":27,\"length\":7,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":35,\"length\":39,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":75,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":26,\"style\":\"fontsize-16\"},{\"offset\":27,\"length\":7,\"style\":\"fontsize-16\"},{\"offset\":35,\"length\":39,\"style\":\"fontsize-16\"},{\"offset\":75,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":26,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":27,\"length\":7,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":35,\"length\":39,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":75,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"a5ro4\",\"text\":\"// To use it:\\nReactDOM.render(<RandomValue />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":14,\"length\":44,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":14,\"length\":44,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":14,\"length\":44,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":14,\"length\":44,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"1sbtm\",\"text\":\"Any JavaScript expression can go inside those curly braces. This is equivalent to the ${} interpolation syntax in JavaScript template literals.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":85,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":86,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":90,\"length\":34,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":125,\"length\":18,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":85,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":86,\"length\":3,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":90,\"length\":34,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":125,\"length\":18,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":85,\"style\":\"fontsize-21\"},{\"offset\":86,\"length\":3,\"style\":\"fontsize-21\"},{\"offset\":90,\"length\":34,\"style\":\"fontsize-21\"},{\"offset\":125,\"length\":18,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":85,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":86,\"length\":3,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":90,\"length\":34,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":125,\"length\":18,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":86,\"length\":3,\"style\":\"CODE\"},{\"offset\":125,\"length\":17,\"style\":\"color-inherit\"},{\"offset\":125,\"length\":17,\"style\":\"bgcolor-transparent\"}],\"entityRanges\":[{\"offset\":125,\"length\":17,\"key\":8}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bnrr4\",\"text\":\"This is the only constraint inside JSX: only expressions. So, for example, you can’t use a regular if statement, but a ternary expression is ok.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":39,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":40,\"length\":58,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":99,\"length\":2,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":102,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":39,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":40,\"length\":58,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":99,\"length\":2,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":102,\"length\":42,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":39,\"style\":\"fontsize-21\"},{\"offset\":40,\"length\":58,\"style\":\"fontsize-21\"},{\"offset\":99,\"length\":2,\"style\":\"fontsize-21\"},{\"offset\":102,\"length\":42,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":39,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":40,\"length\":58,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":99,\"length\":2,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":102,\"length\":42,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":40,\"length\":16,\"style\":\"bgcolor-transparent\"},{\"offset\":99,\"length\":2,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"4un4r\",\"text\":\"JavaScript variables are also expressions, so when the component receives a list of props (the RandomValue component didn’t, props are optional), you can use these props inside curly braces. We did this in the Button component above (Example 1).\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":94,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":95,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":107,\"length\":17,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":125,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":131,\"length\":78,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":210,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":217,\"length\":28,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":94,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":95,\"length\":11,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":107,\"length\":17,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":125,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":131,\"length\":78,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":210,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":217,\"length\":28,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":94,\"style\":\"fontsize-21\"},{\"offset\":95,\"length\":11,\"style\":\"fontsize-21\"},{\"offset\":107,\"length\":17,\"style\":\"fontsize-21\"},{\"offset\":125,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":131,\"length\":78,\"style\":\"fontsize-21\"},{\"offset\":210,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":217,\"length\":28,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":94,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":95,\"length\":11,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":107,\"length\":17,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":125,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":131,\"length\":78,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":210,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":217,\"length\":28,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":95,\"length\":11,\"style\":\"CODE\"},{\"offset\":125,\"length\":5,\"style\":\"CODE\"},{\"offset\":210,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"7us8p\",\"text\":\"JavaScript objects are also expressions. Sometimes we use a JavaScript object inside curly braces, which makes it look like double curly braces, but it’s really just an object inside curly braces. One use case of that is to pass a CSS style object to the special style attribute in React:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":262,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":263,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":269,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":262,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":263,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":269,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":262,\"style\":\"fontsize-21\"},{\"offset\":263,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":269,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":262,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":263,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":269,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":263,\"length\":5,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"adptf\",\"text\":\"// Example 6 - An object passed to the special React style prop\\n// https://jscomplete.com/repl?j=S1Kw2sFHb\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":63,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":64,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":63,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":64,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":63,\"style\":\"fontsize-16\"},{\"offset\":64,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":63,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":64,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":67,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":67,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":67,\"length\":39,\"key\":9}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"93nhp\",\"text\":\"const ErrorDisplay = ({message}) =>\\n  <div style={ { color: 'red', backgroundColor: 'yellow' } }>\\n    {message}\\n  </div>;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":35,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":36,\"length\":61,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":98,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":112,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":35,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":36,\"length\":61,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":98,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":112,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":35,\"style\":\"fontsize-16\"},{\"offset\":36,\"length\":61,\"style\":\"fontsize-16\"},{\"offset\":98,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":112,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":35,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":36,\"length\":61,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":98,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":112,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"a90bl\",\"text\":\"// Use it:\\nReactDOM.render(\\n  <ErrorDisplay \\n    message=\\\"These aren't the droids you're looking for\\\" \\n  />,\\n  mountNode\\n);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":11,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":28,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":45,\"length\":57,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":103,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":109,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":121,\"length\":2,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":10,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":11,\"length\":16,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":28,\"length\":16,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":45,\"length\":57,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":103,\"length\":5,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":109,\"length\":11,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":121,\"length\":2,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":10,\"style\":\"fontsize-16\"},{\"offset\":11,\"length\":16,\"style\":\"fontsize-16\"},{\"offset\":28,\"length\":16,\"style\":\"fontsize-16\"},{\"offset\":45,\"length\":57,\"style\":\"fontsize-16\"},{\"offset\":103,\"length\":5,\"style\":\"fontsize-16\"},{\"offset\":109,\"length\":11,\"style\":\"fontsize-16\"},{\"offset\":121,\"length\":2,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":10,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":11,\"length\":16,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":28,\"length\":16,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":45,\"length\":57,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":103,\"length\":5,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":109,\"length\":11,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":121,\"length\":2,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"8abnj\",\"text\":\"Note how I destructured only the message out of the props argument. Also note how the style attribute above is a special one (again, it’s not HTML, it’s closer to the DOM API). We use an object as the value of the style attribute. That object defines the styles as if we’re doing so with JavaScript (because we are).\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":11,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":24,\"length\":61,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":86,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":92,\"length\":121,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":214,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":220,\"length\":96,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":10,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":11,\"length\":12,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":24,\"length\":61,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":86,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":92,\"length\":121,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":214,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":220,\"length\":96,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":10,\"style\":\"fontsize-21\"},{\"offset\":11,\"length\":12,\"style\":\"fontsize-21\"},{\"offset\":24,\"length\":61,\"style\":\"fontsize-21\"},{\"offset\":86,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":92,\"length\":121,\"style\":\"fontsize-21\"},{\"offset\":214,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":220,\"length\":96,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":10,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":11,\"length\":12,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":24,\"length\":61,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":86,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":92,\"length\":121,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":214,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":220,\"length\":96,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":11,\"length\":12,\"style\":\"BOLD\"},{\"offset\":86,\"length\":5,\"style\":\"CODE\"},{\"offset\":214,\"length\":5,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"e2d8l\",\"text\":\"You can even use a React element inside JSX, because that too is an expression. Remember, a React element is essentially a function call:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":137,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":137,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":137,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":137,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"2lnjh\",\"text\":\"// Example 7 - Using a React element within {}\\n// https://jscomplete.com/repl?j=SkTLpjYr-\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":46,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":47,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":46,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":47,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":46,\"style\":\"fontsize-16\"},{\"offset\":47,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":46,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":47,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":50,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":50,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":50,\"length\":39,\"key\":10}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"9c5ml\",\"text\":\"const MaybeError = ({errorMessage}) =>\\n  <div>\\n    {errorMessage && <ErrorDisplay message={errorMessage} />}\\n  </div>;\\n \\n// The MaybeError component uses the ErrorDisplay component:\\nconst ErrorDisplay = ({message}) =>\\n  <div style={ { color: 'red', backgroundColor: 'yellow' } }>\\n    {message}\\n  </div>;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":47,\"length\":61,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":109,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":121,\"length\":60,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":182,\"length\":35,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":218,\"length\":61,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":280,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":294,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":7,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":47,\"length\":61,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":109,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":121,\"length\":60,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":182,\"length\":35,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":218,\"length\":61,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":280,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":294,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":7,\"style\":\"fontsize-16\"},{\"offset\":47,\"length\":61,\"style\":\"fontsize-16\"},{\"offset\":109,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":121,\"length\":60,\"style\":\"fontsize-16\"},{\"offset\":182,\"length\":35,\"style\":\"fontsize-16\"},{\"offset\":218,\"length\":61,\"style\":\"fontsize-16\"},{\"offset\":280,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":294,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":7,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":47,\"length\":61,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":109,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":121,\"length\":60,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":182,\"length\":35,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":218,\"length\":61,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":280,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":294,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"3ml8s\",\"text\":\"// Now we can use the MaybeError component:\\nReactDOM.render(\\n  <MaybeError\\n    errorMessage={Math.random() > 0.5 ? 'Not good' : ''}\\n  />,\\n  mountNode\\n);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":44,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":61,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":75,\"length\":56,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":132,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":138,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":150,\"length\":2,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":44,\"length\":16,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":61,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":75,\"length\":56,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":132,\"length\":5,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":138,\"length\":11,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":150,\"length\":2,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":44,\"length\":16,\"style\":\"fontsize-16\"},{\"offset\":61,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":75,\"length\":56,\"style\":\"fontsize-16\"},{\"offset\":132,\"length\":5,\"style\":\"fontsize-16\"},{\"offset\":138,\"length\":11,\"style\":\"fontsize-16\"},{\"offset\":150,\"length\":2,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":44,\"length\":16,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":61,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":75,\"length\":56,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":132,\"length\":5,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":138,\"length\":11,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":150,\"length\":2,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"88lhg\",\"text\":\"The MaybeError component above would only display the ErrorDisplaycomponent if there is an errorMessage string passed to it and an empty div. React considers {true}, {false}, {undefined}, and {null} to be valid element children, which do not render anything.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":4,\"length\":10,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":15,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":54,\"length\":36,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":91,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":104,\"length\":32,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":137,\"length\":20,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":158,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":166,\"length\":8,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":175,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":192,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":199,\"length\":59,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":3,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":4,\"length\":10,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":15,\"length\":38,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":54,\"length\":36,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":91,\"length\":12,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":104,\"length\":32,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":137,\"length\":20,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":158,\"length\":7,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":166,\"length\":8,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":175,\"length\":16,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":192,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":199,\"length\":59,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-21\"},{\"offset\":4,\"length\":10,\"style\":\"fontsize-21\"},{\"offset\":15,\"length\":38,\"style\":\"fontsize-21\"},{\"offset\":54,\"length\":36,\"style\":\"fontsize-21\"},{\"offset\":91,\"length\":12,\"style\":\"fontsize-21\"},{\"offset\":104,\"length\":32,\"style\":\"fontsize-21\"},{\"offset\":137,\"length\":20,\"style\":\"fontsize-21\"},{\"offset\":158,\"length\":7,\"style\":\"fontsize-21\"},{\"offset\":166,\"length\":8,\"style\":\"fontsize-21\"},{\"offset\":175,\"length\":16,\"style\":\"fontsize-21\"},{\"offset\":192,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":199,\"length\":59,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":10,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":15,\"length\":38,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":54,\"length\":36,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":91,\"length\":12,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":104,\"length\":32,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":137,\"length\":20,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":158,\"length\":7,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":166,\"length\":8,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":175,\"length\":16,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":192,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":199,\"length\":59,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":10,\"style\":\"CODE\"},{\"offset\":54,\"length\":12,\"style\":\"CODE\"},{\"offset\":91,\"length\":12,\"style\":\"CODE\"},{\"offset\":137,\"length\":3,\"style\":\"CODE\"},{\"offset\":158,\"length\":6,\"style\":\"CODE\"},{\"offset\":166,\"length\":7,\"style\":\"CODE\"},{\"offset\":175,\"length\":11,\"style\":\"CODE\"},{\"offset\":192,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"dbsht\",\"text\":\"You can also use all of JavaScript functional methods on collections (map, reduce, filter, concat, and so on) inside JSX. Again, because they return expressions:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":74,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":75,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":83,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":91,\"length\":70,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":74,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":75,\"length\":7,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":83,\"length\":7,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":91,\"length\":70,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":74,\"style\":\"fontsize-21\"},{\"offset\":75,\"length\":7,\"style\":\"fontsize-21\"},{\"offset\":83,\"length\":7,\"style\":\"fontsize-21\"},{\"offset\":91,\"length\":70,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":74,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":75,\"length\":7,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":83,\"length\":7,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":91,\"length\":70,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":70,\"length\":3,\"style\":\"CODE\"},{\"offset\":75,\"length\":6,\"style\":\"CODE\"},{\"offset\":83,\"length\":6,\"style\":\"CODE\"},{\"offset\":91,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"1ud45\",\"text\":\"// Example 8 - Using an array map inside {}\\n// https://jscomplete.com/repl?j=SJ29aiYH-\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":44,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":44,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":44,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":44,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":47,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":47,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":47,\"length\":39,\"key\":11}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"9qj9g\",\"text\":\"const Doubler = ({value=[1, 2, 3]}) =>\\n  <div>\\n    {value.map(e => e * 2)}\\n  </div>;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":47,\"length\":27,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":75,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":7,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":47,\"length\":27,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":75,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":7,\"style\":\"fontsize-16\"},{\"offset\":47,\"length\":27,\"style\":\"fontsize-16\"},{\"offset\":75,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":7,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":47,\"length\":27,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":75,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"8q6it\",\"text\":\"// Use it\\nReactDOM.render(<Doubler />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":40,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":40,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":40,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":40,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bv5vu\",\"text\":\"Note how I gave the value prop a default value above, because it’s all just Javascript. Note also that I outputted an array expression inside the div. React is okay with that; It will place every doubled value in a text node.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":20,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":26,\"length\":119,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":146,\"length\":79,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":20,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":26,\"length\":119,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":146,\"length\":79,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":20,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":26,\"length\":119,\"style\":\"fontsize-21\"},{\"offset\":146,\"length\":79,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":20,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":26,\"length\":119,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":146,\"length\":79,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":20,\"length\":5,\"style\":\"CODE\"},{\"offset\":146,\"length\":3,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"9avr6\",\"text\":\"Fundamental #4: You can write React components with JavaScript classes\",\"type\":\"header-three\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":70,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":70,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":70,\"style\":\"fontsize-34\"},{\"offset\":0,\"length\":70,\"style\":\"fontfamily-medium-content-sans-serif-font, \\\"Lucida Grande\\\", \\\"Lucida Sans Unicode\\\", \\\"Lucida Sans\\\", Geneva, Arial, sans-serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"clsfk\",\"text\":\"Simple function components are great for simple needs, but sometimes we need more. React supports creating components through the JavaScript class syntax as well. Here’s the Button component (in Example 1) written with the class syntax:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":129,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":130,\"length\":23,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":154,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":174,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":181,\"length\":55,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":129,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":130,\"length\":23,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":154,\"length\":19,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":174,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":181,\"length\":55,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":129,\"style\":\"fontsize-21\"},{\"offset\":130,\"length\":23,\"style\":\"fontsize-21\"},{\"offset\":154,\"length\":19,\"style\":\"fontsize-21\"},{\"offset\":174,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":181,\"length\":55,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":129,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":130,\"length\":23,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":154,\"length\":19,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":174,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":181,\"length\":55,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":130,\"length\":23,\"style\":\"color-inherit\"},{\"offset\":130,\"length\":23,\"style\":\"bgcolor-transparent\"},{\"offset\":174,\"length\":6,\"style\":\"CODE\"}],\"entityRanges\":[{\"offset\":130,\"length\":23,\"key\":12}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"23lnl\",\"text\":\"// Example 9 - Creating components using JavaScript classes\\n// https://jscomplete.com/repl?j=ryjk0iKHb\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":59,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":60,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":59,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":60,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":59,\"style\":\"fontsize-16\"},{\"offset\":60,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":59,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":60,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":9,\"style\":\"BOLD\"},{\"offset\":63,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":63,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":63,\"length\":39,\"key\":13}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"5kn8h\",\"text\":\"class Button extends React.Component {\\n  render() {\\n    return <button>{this.props.label}</button>;\\n  }\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":52,\"length\":47,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":100,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":104,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":52,\"length\":47,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":100,\"length\":3,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":104,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":52,\"length\":47,\"style\":\"fontsize-16\"},{\"offset\":100,\"length\":3,\"style\":\"fontsize-16\"},{\"offset\":104,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":52,\"length\":47,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":100,\"length\":3,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":104,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"c1opl\",\"text\":\"// Use it (same syntax)\\nReactDOM.render(<Button label=\\\"Save\\\" />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":23,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":24,\"length\":52,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":23,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":24,\"length\":52,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":23,\"style\":\"fontsize-16\"},{\"offset\":24,\"length\":52,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":23,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":24,\"length\":52,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"c1bok\",\"text\":\"The class syntax is simple. Define a class that extends React.Component(another top-level React API thing that you need to learn). The class defines a single instance function render(), and that render function returns the virtual DOM element. Every time we use the Button class-based component above (for example, by doing <Button ... />), React will instantiate an object from this class-based component and use that object to render a DOM element in the DOM tree.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":55,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":56,\"length\":119,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":176,\"length\":89,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":266,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":273,\"length\":50,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":324,\"length\":142,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":55,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":56,\"length\":119,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":176,\"length\":89,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":266,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":273,\"length\":50,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":324,\"length\":142,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":55,\"style\":\"fontsize-21\"},{\"offset\":56,\"length\":119,\"style\":\"fontsize-21\"},{\"offset\":176,\"length\":89,\"style\":\"fontsize-21\"},{\"offset\":266,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":273,\"length\":50,\"style\":\"fontsize-21\"},{\"offset\":324,\"length\":142,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":55,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":56,\"length\":119,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":176,\"length\":89,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":266,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":273,\"length\":50,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":324,\"length\":142,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":56,\"length\":15,\"style\":\"CODE\"},{\"offset\":176,\"length\":8,\"style\":\"CODE\"},{\"offset\":266,\"length\":6,\"style\":\"CODE\"},{\"offset\":324,\"length\":14,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"109u9\",\"text\":\"This is the reason why we used this.props.label inside the JSX in the rendered output above. Because every element rendered through a class component gets a special instance property called props that holds all values passed to that element when it was created.\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":30,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":31,\"length\":16,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":48,\"length\":116,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":165,\"length\":8,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":174,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":190,\"length\":5,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":196,\"length\":65,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":30,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":31,\"length\":16,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":48,\"length\":116,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":165,\"length\":8,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":174,\"length\":15,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":190,\"length\":5,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":196,\"length\":65,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":30,\"style\":\"fontsize-21\"},{\"offset\":31,\"length\":16,\"style\":\"fontsize-21\"},{\"offset\":48,\"length\":116,\"style\":\"fontsize-21\"},{\"offset\":165,\"length\":8,\"style\":\"fontsize-21\"},{\"offset\":174,\"length\":15,\"style\":\"fontsize-21\"},{\"offset\":190,\"length\":5,\"style\":\"fontsize-21\"},{\"offset\":196,\"length\":65,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":30,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":31,\"length\":16,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":48,\"length\":116,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":165,\"length\":8,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":174,\"length\":15,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":190,\"length\":5,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":196,\"length\":65,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":31,\"length\":16,\"style\":\"CODE\"},{\"offset\":190,\"length\":5,\"style\":\"CODE\"},{\"offset\":165,\"length\":8,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"7tcgt\",\"text\":\"Since we have an instance associated with a single use of the component, we can customize that instance as we wish. We can, for example, customize it after it gets constructed by using the regular JavaScript constructorfunction:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":207,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":208,\"length\":20,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":207,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":208,\"length\":20,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":207,\"style\":\"fontsize-21\"},{\"offset\":208,\"length\":20,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":207,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":208,\"length\":20,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":208,\"length\":11,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"cl6kv\",\"text\":\"// Example 10 -  Customizing a component instance\\n// https://jscomplete.com/repl?j=rko7RsKS-\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":49,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":50,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":49,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":50,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":49,\"style\":\"fontsize-16\"},{\"offset\":50,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":49,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":50,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":10,\"style\":\"BOLD\"},{\"offset\":53,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":53,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":53,\"length\":39,\"key\":14}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"cgu02\",\"text\":\"class Button extends React.Component {\\n  constructor(props) {\\n    super(props);\\n    this.id = Date.now();\\n  }\\n  render() {\\n    return <button id={this.id}>{this.props.label}</button>;\\n  }\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":62,\"length\":17,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":80,\"length\":25,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":106,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":110,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":123,\"length\":60,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":184,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":188,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":22,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":62,\"length\":17,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":80,\"length\":25,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":106,\"length\":3,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":110,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":123,\"length\":60,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":184,\"length\":3,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":188,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":22,\"style\":\"fontsize-16\"},{\"offset\":62,\"length\":17,\"style\":\"fontsize-16\"},{\"offset\":80,\"length\":25,\"style\":\"fontsize-16\"},{\"offset\":106,\"length\":3,\"style\":\"fontsize-16\"},{\"offset\":110,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":123,\"length\":60,\"style\":\"fontsize-16\"},{\"offset\":184,\"length\":3,\"style\":\"fontsize-16\"},{\"offset\":188,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":22,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":62,\"length\":17,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":80,\"length\":25,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":106,\"length\":3,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":110,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":123,\"length\":60,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":184,\"length\":3,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":188,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"asc16\",\"text\":\"// Use it\\nReactDOM.render(<Button label=\\\"Save\\\" />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":52,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":52,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":52,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":52,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"ebnrg\",\"text\":\"We can also define class functions and use them anywhere we wish, including inside the returned JSX output:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":107,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":107,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":107,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":107,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"chupp\",\"text\":\"// Example 11 — Using class properties\\n// https://jscomplete.com/repl?j=H1YDCoFSb\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":10,\"style\":\"BOLD\"},{\"offset\":42,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":42,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":42,\"length\":39,\"key\":15}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"garo\",\"text\":\"class Button extends React.Component {\\n  clickCounter = 0;\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":38,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":39,\"length\":19,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":38,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":39,\"length\":19,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":38,\"style\":\"fontsize-16\"},{\"offset\":39,\"length\":19,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":38,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":39,\"length\":19,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"f1jhu\",\"text\":\"  handleClick = () => {\\n    console.log(`Clicked: ${++this.clickCounter}`);\\n  };\\n \\n  render() {\\n    return (\\n      <button id={this.id} onClick={this.handleClick}>\\n        {this.props.label}\\n      </button>\\n    );\\n  }\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":23,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":24,\"length\":51,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":76,\"length\":4,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":83,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":96,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":109,\"length\":54,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":164,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":191,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":207,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":214,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":218,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":23,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":24,\"length\":51,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":76,\"length\":4,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":83,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":96,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":109,\"length\":54,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":164,\"length\":26,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":191,\"length\":15,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":207,\"length\":6,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":214,\"length\":3,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":218,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":23,\"style\":\"fontsize-16\"},{\"offset\":24,\"length\":51,\"style\":\"fontsize-16\"},{\"offset\":76,\"length\":4,\"style\":\"fontsize-16\"},{\"offset\":83,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":96,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":109,\"length\":54,\"style\":\"fontsize-16\"},{\"offset\":164,\"length\":26,\"style\":\"fontsize-16\"},{\"offset\":191,\"length\":15,\"style\":\"fontsize-16\"},{\"offset\":207,\"length\":6,\"style\":\"fontsize-16\"},{\"offset\":214,\"length\":3,\"style\":\"fontsize-16\"},{\"offset\":218,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":23,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":24,\"length\":51,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":76,\"length\":4,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":83,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":96,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":109,\"length\":54,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":164,\"length\":26,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":191,\"length\":15,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":207,\"length\":6,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":214,\"length\":3,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":218,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"33ruj\",\"text\":\"// Use it\\nReactDOM.render(<Button label=\\\"Save\\\" />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":52,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":52,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":52,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":52,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bvimb\",\"text\":\"Note a few things about Example 11 above:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":41,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":41,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":41,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":41,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"avuhe\",\"text\":\"The handleClick function is written using the new proposed class-field syntax in JavaScript. This is still at stage-2, but for many reasons it’s the best option to access the component mounted instance (thanks to arrow functions). But, you need to use a compiler like Babel configured to understand stage-2 (or the class-field syntax) to get the code above to work. The jsComplete REPL has that pre-configured.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":4,\"length\":11,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":16,\"length\":42,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":59,\"length\":18,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":78,\"length\":332,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":59,\"length\":18,\"style\":\"bgcolor-transparent\"},{\"offset\":4,\"length\":11,\"style\":\"CODE\"},{\"offset\":59,\"length\":18,\"style\":\"color-inherit\"},{\"offset\":0,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":4,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":16,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":59,\"length\":18,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":78,\"length\":332,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":3,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":4,\"length\":11,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":16,\"length\":42,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":59,\"length\":18,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":78,\"length\":332,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":3,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":4,\"length\":11,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":16,\"length\":42,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":59,\"length\":18,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":78,\"length\":332,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-20\"},{\"offset\":4,\"length\":11,\"style\":\"fontsize-20\"},{\"offset\":16,\"length\":42,\"style\":\"fontsize-20\"},{\"offset\":59,\"length\":18,\"style\":\"fontsize-20\"},{\"offset\":78,\"length\":332,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":3,\"style\":\"fontsize-21\"},{\"offset\":4,\"length\":11,\"style\":\"fontsize-21\"},{\"offset\":16,\"length\":42,\"style\":\"fontsize-21\"},{\"offset\":59,\"length\":18,\"style\":\"fontsize-21\"},{\"offset\":78,\"length\":332,\"style\":\"fontsize-21\"}],\"entityRanges\":[{\"offset\":59,\"length\":18,\"key\":16}],\"data\":{}},{\"key\":\"vat0\",\"text\":\"We’ve also defined the clickCounter instance variables using the same class-field syntax. This allows us to skip using a class constructor call altogether.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":23,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":36,\"length\":119,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":23,\"length\":12,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":36,\"length\":119,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":22,\"style\":\"fontsize-20\"},{\"offset\":23,\"length\":12,\"style\":\"fontsize-20\"},{\"offset\":36,\"length\":119,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":22,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":23,\"length\":12,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":36,\"length\":119,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":23,\"length\":12,\"style\":\"fontsize-21\"},{\"offset\":36,\"length\":119,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":12,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":36,\"length\":119,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":23,\"length\":12,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"di82f\",\"text\":\"When we specified the handleClick function as the value of the special onClick React attribute, we did not call it. We passed in the reference to the handleClick function. Calling the function on that level is one of the most common mistakes when working with React.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":21,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":22,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":34,\"length\":36,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":71,\"length\":7,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":79,\"length\":53,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":133,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":143,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":150,\"length\":11,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":162,\"length\":104,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":21,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":22,\"length\":11,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":34,\"length\":36,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":71,\"length\":7,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":79,\"length\":53,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":133,\"length\":9,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":143,\"length\":6,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":150,\"length\":11,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":162,\"length\":104,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":21,\"style\":\"fontsize-20\"},{\"offset\":22,\"length\":11,\"style\":\"fontsize-20\"},{\"offset\":34,\"length\":36,\"style\":\"fontsize-20\"},{\"offset\":71,\"length\":7,\"style\":\"fontsize-20\"},{\"offset\":79,\"length\":53,\"style\":\"fontsize-20\"},{\"offset\":133,\"length\":9,\"style\":\"fontsize-20\"},{\"offset\":143,\"length\":6,\"style\":\"fontsize-20\"},{\"offset\":150,\"length\":11,\"style\":\"fontsize-20\"},{\"offset\":162,\"length\":104,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":21,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":22,\"length\":11,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":34,\"length\":36,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":71,\"length\":7,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":79,\"length\":53,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":133,\"length\":9,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":143,\"length\":6,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":150,\"length\":11,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":162,\"length\":104,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":21,\"style\":\"fontsize-21\"},{\"offset\":22,\"length\":11,\"style\":\"fontsize-21\"},{\"offset\":34,\"length\":36,\"style\":\"fontsize-21\"},{\"offset\":71,\"length\":7,\"style\":\"fontsize-21\"},{\"offset\":79,\"length\":53,\"style\":\"fontsize-21\"},{\"offset\":133,\"length\":9,\"style\":\"fontsize-21\"},{\"offset\":143,\"length\":6,\"style\":\"fontsize-21\"},{\"offset\":150,\"length\":11,\"style\":\"fontsize-21\"},{\"offset\":162,\"length\":104,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":21,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":22,\"length\":11,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":34,\"length\":36,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":71,\"length\":7,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":79,\"length\":53,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":133,\"length\":9,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":143,\"length\":6,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":150,\"length\":11,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":162,\"length\":104,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":22,\"length\":11,\"style\":\"CODE\"},{\"offset\":71,\"length\":7,\"style\":\"CODE\"},{\"offset\":150,\"length\":11,\"style\":\"CODE\"},{\"offset\":133,\"length\":9,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"8btn1\",\"text\":\"// Wrong:\\nonClick={this.handleClick()}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":28,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":28,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":28,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":28,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":19,\"length\":18,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"61qk3\",\"text\":\"// Right:\\nonClick={this.handleClick}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":26,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":26,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":26,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":19,\"length\":16,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"d5afq\",\"text\":\"Fundamental #5: Events in React: Two Important Differences\",\"type\":\"header-three\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":58,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":58,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":58,\"style\":\"fontsize-34\"},{\"offset\":0,\"length\":58,\"style\":\"fontfamily-medium-content-sans-serif-font, \\\"Lucida Grande\\\", \\\"Lucida Sans Unicode\\\", \\\"Lucida Sans\\\", Geneva, Arial, sans-serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"bd7ls\",\"text\":\"When handling events inside React elements, there are two very important differences from the way we do so with the DOM API:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":124,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":124,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":124,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":124,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"2nd5m\",\"text\":\"All React elements attributes (events included) are named using camelCase, rather than lowercase. It’s onClick, not onclick.\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":63,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":64,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":87,\"length\":15,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":103,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":116,\"length\":8,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":63,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":64,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":87,\"length\":15,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":103,\"length\":12,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":116,\"length\":8,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":63,\"style\":\"fontsize-20\"},{\"offset\":64,\"length\":22,\"style\":\"fontsize-20\"},{\"offset\":87,\"length\":15,\"style\":\"fontsize-20\"},{\"offset\":103,\"length\":12,\"style\":\"fontsize-20\"},{\"offset\":116,\"length\":8,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":63,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":64,\"length\":22,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":87,\"length\":15,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":103,\"length\":12,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":116,\"length\":8,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":63,\"style\":\"fontsize-21\"},{\"offset\":64,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":87,\"length\":15,\"style\":\"fontsize-21\"},{\"offset\":103,\"length\":12,\"style\":\"fontsize-21\"},{\"offset\":116,\"length\":8,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":63,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":64,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":87,\"length\":15,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":103,\"length\":12,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":116,\"length\":8,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":64,\"length\":9,\"style\":\"BOLD\"},{\"offset\":87,\"length\":9,\"style\":\"BOLD\"},{\"offset\":103,\"length\":7,\"style\":\"CODE\"},{\"offset\":116,\"length\":7,\"style\":\"CODE\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"fs267\",\"text\":\"We pass an actual JavaScript function reference as the event handler, rather than a string. It’s onClick={handleClick}, not onClick=\\\"handleClick\\\".\",\"type\":\"unordered-list-item\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":96,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":97,\"length\":26,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":124,\"length\":22,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":96,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":97,\"length\":26,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":124,\"length\":22,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":96,\"style\":\"fontsize-20\"},{\"offset\":97,\"length\":26,\"style\":\"fontsize-20\"},{\"offset\":124,\"length\":22,\"style\":\"fontsize-20\"},{\"offset\":0,\"length\":96,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":97,\"length\":26,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":124,\"length\":22,\"style\":\"fontfamily-medium-content-sans-serif-font, -apple-system, system-ui, \\\"Segoe UI\\\", Roboto, Oxygen, Ubuntu, Cantarell, \\\"Open Sans\\\", \\\"Helvetica Neue\\\", sans-serif\"},{\"offset\":0,\"length\":96,\"style\":\"fontsize-21\"},{\"offset\":97,\"length\":26,\"style\":\"fontsize-21\"},{\"offset\":124,\"length\":22,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":96,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":97,\"length\":26,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":124,\"length\":22,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"},{\"offset\":97,\"length\":21,\"style\":\"CODE\"},{\"offset\":124,\"length\":21,\"style\":\"CODE\"},{\"offset\":106,\"length\":11,\"style\":\"BOLD\"},{\"offset\":133,\"length\":12,\"style\":\"BOLD\"}],\"entityRanges\":[],\"data\":{}},{\"key\":\"c5jn4\",\"text\":\"React wraps the DOM event object with an object of its own to optimize the performance of events handling. But inside an event handler, we can still access all methods available on the DOM event object. React passes that wrapped event object to every handle call. For example, to prevent a form from the default submission action, you can do:\",\"type\":\"unstyled\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":342,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":342,\"style\":\"bgcolor-rgb(255,255,255)\"},{\"offset\":0,\"length\":342,\"style\":\"fontsize-21\"},{\"offset\":0,\"length\":342,\"style\":\"fontfamily-medium-content-serif-font, Georgia, Cambria, \\\"Times New Roman\\\", Times, serif\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"31cjt\",\"text\":\"// Example 12 - Working with wrapped events\\n// https://jscomplete.com/repl?j=HkIhRoKBb\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":43,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":44,\"length\":42,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":43,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":44,\"length\":42,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":43,\"style\":\"fontsize-16\"},{\"offset\":44,\"length\":42,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":43,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":44,\"length\":42,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":3,\"length\":10,\"style\":\"BOLD\"},{\"offset\":47,\"length\":39,\"style\":\"color-inherit\"},{\"offset\":47,\"length\":39,\"style\":\"bgcolor-initial\"}],\"entityRanges\":[{\"offset\":47,\"length\":39,\"key\":17}],\"data\":{\"text-align\":\"start\"}},{\"key\":\"7aqqu\",\"text\":\"class Form extends React.Component {\\n  handleSubmit = (event) => {\\n    event.preventDefault();\\n    console.log('Form submitted');\\n  };\\n \\n  render() {\\n    return (\\n      <form onSubmit={this.handleSubmit}>\\n        <button type=\\\"submit\\\">Submit</button>\\n      </form>\\n    );\\n  }\\n}\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":36,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":37,\"length\":29,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":67,\"length\":27,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":95,\"length\":34,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":130,\"length\":4,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":137,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":150,\"length\":12,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":163,\"length\":41,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":205,\"length\":45,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":251,\"length\":13,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":265,\"length\":6,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":272,\"length\":3,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":276,\"length\":1,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":36,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":37,\"length\":29,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":67,\"length\":27,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":95,\"length\":34,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":130,\"length\":4,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":137,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":150,\"length\":12,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":163,\"length\":41,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":205,\"length\":45,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":251,\"length\":13,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":265,\"length\":6,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":272,\"length\":3,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":276,\"length\":1,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":36,\"style\":\"fontsize-16\"},{\"offset\":37,\"length\":29,\"style\":\"fontsize-16\"},{\"offset\":67,\"length\":27,\"style\":\"fontsize-16\"},{\"offset\":95,\"length\":34,\"style\":\"fontsize-16\"},{\"offset\":130,\"length\":4,\"style\":\"fontsize-16\"},{\"offset\":137,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":150,\"length\":12,\"style\":\"fontsize-16\"},{\"offset\":163,\"length\":41,\"style\":\"fontsize-16\"},{\"offset\":205,\"length\":45,\"style\":\"fontsize-16\"},{\"offset\":251,\"length\":13,\"style\":\"fontsize-16\"},{\"offset\":265,\"length\":6,\"style\":\"fontsize-16\"},{\"offset\":272,\"length\":3,\"style\":\"fontsize-16\"},{\"offset\":276,\"length\":1,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":36,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":37,\"length\":29,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":67,\"length\":27,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":95,\"length\":34,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":130,\"length\":4,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":137,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":150,\"length\":12,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":163,\"length\":41,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":205,\"length\":45,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":251,\"length\":13,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":265,\"length\":6,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":272,\"length\":3,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":276,\"length\":1,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}},{\"key\":\"cr02j\",\"text\":\"// Use it\\nReactDOM.render(<Form />, mountNode);\",\"type\":\"code\",\"depth\":0,\"inlineStyleRanges\":[{\"offset\":0,\"length\":9,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":10,\"length\":37,\"style\":\"color-rgba(0,0,0,0.84)\"},{\"offset\":0,\"length\":9,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":10,\"length\":37,\"style\":\"bgcolor-rgba(0,0,0,0.05)\"},{\"offset\":0,\"length\":9,\"style\":\"fontsize-16\"},{\"offset\":10,\"length\":37,\"style\":\"fontsize-16\"},{\"offset\":0,\"length\":9,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"},{\"offset\":10,\"length\":37,\"style\":\"fontfamily-Menlo, Monaco, \\\"Courier New\\\", Courier, monospace\"}],\"entityRanges\":[],\"data\":{\"text-align\":\"start\"}}],\"entityMap\":{\"0\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=Sy3QAdKHW\",\"title\":\"https://jscomplete.com/repl?j=Sy3QAdKHW\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=Sy3QAdKHW\",\"title\":\"https://jscomplete.com/repl?j=Sy3QAdKHW\",\"targetOption\":\"_blank\"}}}},\"1\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/react/\",\"title\":\"jsComplete React Playground\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/react/\",\"title\":\"jsComplete React Playground\",\"targetOption\":\"_blank\"}}}},\"2\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=HyiEwoYB-\",\"title\":\"https://jscomplete.com/repl?j=HyiEwoYB-\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=HyiEwoYB-\",\"title\":\"https://jscomplete.com/repl?j=HyiEwoYB-\",\"targetOption\":\"_blank\"}}}},\"3\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=r1GNoiFBb\",\"title\":\"https://jscomplete.com/repl?j=r1GNoiFBb\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=r1GNoiFBb\",\"title\":\"https://jscomplete.com/repl?j=r1GNoiFBb\",\"targetOption\":\"_blank\"}}}},\"4\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://google.com/search\",\"title\":\"https://google.com/search\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://google.com/search\",\"title\":\"https://google.com/search\",\"targetOption\":\"_blank\"}}}},\"5\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SJWy3otHW\",\"title\":\"https://jscomplete.com/repl?j=SJWy3otHW\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SJWy3otHW\",\"title\":\"https://jscomplete.com/repl?j=SJWy3otHW\",\"targetOption\":\"_blank\"}}}},\"6\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://google.com/search\",\"title\":\"https://google.com/search\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://google.com/search\",\"title\":\"https://google.com/search\",\"targetOption\":\"_blank\"}}}},\"7\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SkNN3oYSW\",\"title\":\"https://jscomplete.com/repl?j=SkNN3oYSW\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SkNN3oYSW\",\"title\":\"https://jscomplete.com/repl?j=SkNN3oYSW\",\"targetOption\":\"_blank\"}}}},\"8\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals\",\"title\":\"template literals\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals\",\"title\":\"template literals\",\"targetOption\":\"_blank\"}}}},\"9\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=S1Kw2sFHb\",\"title\":\"https://jscomplete.com/repl?j=S1Kw2sFHb\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=S1Kw2sFHb\",\"title\":\"https://jscomplete.com/repl?j=S1Kw2sFHb\",\"targetOption\":\"_blank\"}}}},\"10\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SkTLpjYr-\",\"title\":\"https://jscomplete.com/repl?j=SkTLpjYr-\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SkTLpjYr-\",\"title\":\"https://jscomplete.com/repl?j=SkTLpjYr-\",\"targetOption\":\"_blank\"}}}},\"11\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SJ29aiYH-\",\"title\":\"https://jscomplete.com/repl?j=SJ29aiYH-\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=SJ29aiYH-\",\"title\":\"https://jscomplete.com/repl?j=SJ29aiYH-\",\"targetOption\":\"_blank\"}}}},\"12\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes\",\"title\":\"JavaScript class syntax\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes\",\"title\":\"JavaScript class syntax\",\"targetOption\":\"_blank\"}}}},\"13\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=ryjk0iKHb\",\"title\":\"https://jscomplete.com/repl?j=ryjk0iKHb\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=ryjk0iKHb\",\"title\":\"https://jscomplete.com/repl?j=ryjk0iKHb\",\"targetOption\":\"_blank\"}}}},\"14\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=rko7RsKS-\",\"title\":\"https://jscomplete.com/repl?j=rko7RsKS-\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=rko7RsKS-\",\"title\":\"https://jscomplete.com/repl?j=rko7RsKS-\",\"targetOption\":\"_blank\"}}}},\"15\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=H1YDCoFSb\",\"title\":\"https://jscomplete.com/repl?j=H1YDCoFSb\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=H1YDCoFSb\",\"title\":\"https://jscomplete.com/repl?j=H1YDCoFSb\",\"targetOption\":\"_blank\"}}}},\"16\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://github.com/tc39/proposal-class-fields\",\"title\":\"class-field syntax\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://github.com/tc39/proposal-class-fields\",\"title\":\"class-field syntax\",\"targetOption\":\"_blank\"}}}},\"17\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=HkIhRoKBb\",\"title\":\"https://jscomplete.com/repl?j=HkIhRoKBb\",\"targetOption\":\"_blank\",\"_map\":{\"type\":\"LINK\",\"mutability\":\"MUTABLE\",\"data\":{\"url\":\"https://jscomplete.com/repl?j=HkIhRoKBb\",\"title\":\"https://jscomplete.com/repl?j=HkIhRoKBb\",\"targetOption\":\"_blank\"}}}}}}"}'''

# %%
len(base64.b64encode(text.encode('utf-8')).decode('ascii'))
# Out:
# 193168

# %%
text.encode('utf-8')
# Out:
# b'{"collaborators":[],"title":"fundamental React.js concepts","explicit_tags":["react","js","tutorial"],"body":"{"blocks":[{"key":"escdl","text":"Fundamental #1: React is all about components","type":"header-three","depth":0,"inlineStyleRanges":[{"offset":0,"length":45,"style":"color-rgba(0,0,0,0.84)"},{"offset":0,"length":45,"style":"bgcolor-rgb(255,255,255)"},{"offset":0,"length":45,"style":"fontsize-34"},{"offset":0,"length":45,"style":"fontfamily-medium-content-sans-serif-font, \\"Lucida Grande\\", \\"Lucida Sans Unicode\\", \\"Lucida Sans\\", Geneva, Arial, sans-serif"}],"entityRanges":[],"data":{"text-align":"start"}},{"key":"2o5cc","text":"React is designed around the concept of reusable components. You define small components and you put them together to form bigger components.","type":"unstyled","depth":0,"inlineStyleRanges":[{"offset":0,"length":141,"style":"color-rgba(0,0,0,0.84)"},{"offset":0,"length":141,"style":"bgcolor-rgb(255,255,255)"},{"offset":0,"length":141,"style
# ...

# %%
len(text)
# Out:
# 144802

# %%
j = json.loads(text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-7750463cecd1> in <module>()
# ----> 1 j = json.loads(text)
#
# /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
# ...
